# %%
import pandas 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
data_siswa = pandas.read_excel('DATA SISWA SMAN 1 CIKEMBAR.xlsX')

# %%
data_siswa.head()
# Out:
#    NO        NIS          NISN                  NAMA INISIAL JK TEMPAT LAHIR  \
# 0   1  121310001  9.956571e+09        ABANG UNGGARAN   ABANG  L     SUKABUMI
# 1   2  121310002  9.956572e+09      ADE SUROSIANA Y.  ADE SU  L     SUKABUMI
# 2   3  121310003  9.976797e+09        ADIATUL RAHMAN  ADIATU  L     SUKABUMI
# 3   4  121310004  9.976497e+09         ADINDA RAHAYU  ADINDA  P     SUKABUMI
# 4   5  121310005  9.966657e+09  ADITYA KUMAEDI HARUN  ADITYA  L     SUKABUMI
#
#          TANGGAL LAHIR                  ALAMAT KELAS WARGA NEGARA  \
# 0  1995-11-15 00:00:00  Jln Pelabuhan II Km.20    X3          WNI
# 1  1996-11-02 00:00:00  Jln Pelabuhan II Km.20    X6          WNI
# 2  1996-04-29 00:00:00  Jln Pelabuhan II Km.20    X4          WNI
# 3  1997-01-02 00:00:00  Jln Pelabuhan II Km.20    X5          WNI
# 4  1996-10-03 00:00:00  Jln Pelabuhan II Km.20    X7          WNI
#
#   TANGGAL DITERIMA
# 0       2012-07-06
# 1       2012-07-06
# 2       2012-07-06
# 3       2012-07-06
# ...

# %%
data_siswa.shape
# Out:
# (901, 12)

# %%
data_siswa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 12 columns):
# NO                  901 non-null int64
# NIS                 901 non-null int64
# NISN                539 non-null float64
# NAMA                901 non-null object
# INISIAL             901 non-null object
# JK                  901 non-null object
# TEMPAT LAHIR        901 non-null object
# TANGGAL LAHIR       901 non-null object
# ALAMAT              901 non-null object
# KELAS               901 non-null object
# WARGA NEGARA        901 non-null object
# TANGGAL DITERIMA    901 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 84.6+ KB

# %%
data_siswa['KELAS' ].value_counts()
# Out:
# XII IPS 2    48
# X6           46
# X3           46
# X2           46
# XII IPS 1    46
# X5           46
# X7           46
# X4           46
# XII IPS 3    44
# XI A 3       43
# XI A 1       43
# X1           43
# XI A 2       42
# XII IPA 3    41
# XI S 3       40
# XI S 1       40
# XI S 4       40
# XI S 2       39
# XII IPA 1    39
# XII IPA 2    37
# XII IPS 4    21
# XII IPA 4    18
# XII IPA       1
# Name: KELAS, dtype: int64

# %%
data_siswa[['TANGGAL DITERIMA','NISN','NAMA']]
# Out:
#     TANGGAL DITERIMA          NISN                  NAMA
# 0         2012-07-06  9.956571e+09        ABANG UNGGARAN
# 1         2012-07-06  9.956572e+09      ADE SUROSIANA Y.
# 2         2012-07-06  9.976797e+09        ADIATUL RAHMAN
# 3         2012-07-06  9.976497e+09         ADINDA RAHAYU
# 4         2012-07-06  9.966657e+09  ADITYA KUMAEDI HARUN
# ..               ...           ...                   ...
# 896       2011-04-22           NaN             YULIAWATI
# 897       2011-04-23           NaN          YUNI SUTINSA
# 898       2011-04-24           NaN     YURISKA SAPTAWATI
# 899       2011-04-25           NaN  ZALLSA BAHARI ACKBAR
# 900       2011-04-26           NaN         ZIARAH AMALIA
#
# [901 rows x 3 columns]

# %%
plt.hist(data_siswa['TANGGAL DITERIMA'], edgecolor='black', linewidth=1)
plt.xlabel('Tanggal Diterimanya Siswa')
plt.ylabel('Jumlah Siswa yang Di terima')
# Out:
# Text(0, 0.5, 'Jumlah Siswa yang Di terima')

# %%
data_siswa.sort_values(by='KELAS', ascending=True)
# Out:
#       NO        NIS          NISN                      NAMA INISIAL JK  \
# 213  214  121310214  9.964243e+09              RANITA JULIA  RANITA  P
# 178  179  121310179  9.966732e+09  MOHAMAD FAISSAL ISMAIL N  MOHAMA  L
# 181  182  121310182  9.964028e+09           MUHAMMAD FARIKI  MUHAMM  L
# 242  243  121310243  9.964219e+09             RINI FEBRIANI  RINI F  P
# 283  284  121310284  9.970768e+09              SITI RUQOYAH  SITI R  P
# ..   ...        ...           ...                       ...     ... ..
# 725  726  101110120           NaN             IHSAN RAYPASA   IHSAN  L
# 694  695  101110089           NaN            FAJAR SUHERLAN   FAJAR  L
# 835  836  101110230           NaN         RISKA YULIA CITRA   RISKA  P
# 643  644  101110038           NaN         AYU GINA KAROLINA   AYU G  P
# 786  787  101110181           NaN              NOGI ANGGARA    NOGI  L
#
#     TEMPAT LAHIR        TANGGAL LAHIR  \
# 213     SUKABUMI  1996-10-17 00:00:00
# ...

# %%
labels = 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7'
sizes = [43, 46, 46, 46, 46, 46, 46]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
labels = 'X', 'XI', 'XII'
sizes = [319, 287, 295]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
